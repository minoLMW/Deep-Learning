# %% [markdown]
# # **1. Segmentation**
# Segmentation은 컴퓨터 비전에서 이미지나 영상을 픽셀 단위로 분할하여 각 영역이 무엇을 나타내는지 구분하는 기술입니다. 이는 크게 Semantic Segmentation과 Instance Segmentation으로 나뉘는데, Semantic Segmentation은 같은 종류의 객체를 동일한 클래스로 분류하는 반면, Instance Segmentation은 같은 클래스 내에서도 개별 객체를 구분합니다. 이를 통해 의료 영상 분석, 자율주행, 위성 이미지 처리 등 다양한 분야에서 정밀한 객체 인식을 수행할 수 있습니다. Segmentation 모델로는 U-Net, DeepLab, Mask R-CNN 등이 널리 사용됩니다.
#
# <img src='https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2FbUla0i%2FbtsMEoFBBFg%2FAAAAAAAAAAAAAAAAAAAAANsTt4jCSTsz_hIMnLIvRyfxueUeIt8B9HAc77CCnSYm%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1756652399%26allow_ip%3D%26allow_referer%3D%26signature%3D9uWb%252B0cOXOPhv7SH5psPKo9bIKA%253D' width=600>

# %%
# !pip install -q ultralytics opencv-python
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 38.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.7 MB/s eta 0:00:00

# %%
import os
import random
import shutil
from tqdm import tqdm
import cv2
import glob
import json
import matplotlib.pyplot as plt
import numpy as np
from pycocotools import mask as maskUtils
from torchvision import transforms

# %%
# !mkdir /content/starbucks

# %%
# !unzip /content/starbucks.zip -d /content/starbucks
# Out:
# Archive:  /content/starbucks.zip
#    creating: /content/starbucks/starbucks/
#   inflating: /content/starbucks/__MACOSX/._starbucks
#   inflating: /content/starbucks/starbucks/starbucks29.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks29.jpg
#   inflating: /content/starbucks/starbucks/starbucks15.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks15.jpg
#   inflating: /content/starbucks/starbucks/starbucks14.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks14.jpg
#   inflating: /content/starbucks/starbucks/starbucks28.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks28.jpg
#   inflating: /content/starbucks/starbucks/starbucks16.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks16.jpg
#   inflating: /content/starbucks/starbucks/starbucks17.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks17.jpg
#   inflating: /content/starbucks/starbucks/starbucks13.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks13.jpg
#   inflating: /content/starbucks/starbucks/.DS_Store
#   inflating: /content/starbucks/__MACOSX/starbucks/._.DS_Store
#   inflating: /content/starbucks/starbucks/starbucks12.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks12.jpg
#   inflating: /content/starbucks/starbucks/starbucks38.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks38.jpg
#   inflating: /content/starbucks/starbucks/starbucks39.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks39.jpg
#   inflating: /content/starbucks/starbucks/starbucks11.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks11.jpg
#   inflating: /content/starbucks/starbucks/starbucks40.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks40.jpg
#   inflating: /content/starbucks/starbucks/instances_default.json
#   inflating: /content/starbucks/__MACOSX/starbucks/._instances_default.json
#   inflating: /content/starbucks/starbucks/starbucks20.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks20.jpg
#   inflating: /content/starbucks/starbucks/starbucks34.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks34.jpg
#   inflating: /content/starbucks/starbucks/starbucks35.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks35.jpg
#   inflating: /content/starbucks/starbucks/starbucks21.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks21.jpg
#   inflating: /content/starbucks/starbucks/starbucks37.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks37.jpg
#   inflating: /content/starbucks/starbucks/starbucks23.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks23.jpg
#   inflating: /content/starbucks/starbucks/starbucks22.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks22.jpg
#   inflating: /content/starbucks/starbucks/starbucks36.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks36.jpg
#   inflating: /content/starbucks/starbucks/starbucks32.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks32.jpg
#   inflating: /content/starbucks/starbucks/starbucks26.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks26.jpg
#    creating: /content/starbucks/starbucks/무제 폴더/
#   inflating: /content/starbucks/starbucks/starbucks27.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks27.jpg
#   inflating: /content/starbucks/starbucks/starbucks33.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks33.jpg
#   inflating: /content/starbucks/starbucks/starbucks25.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks25.jpg
#   inflating: /content/starbucks/starbucks/starbucks31.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks31.jpg
#   inflating: /content/starbucks/starbucks/starbucks19.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks19.jpg
#   inflating: /content/starbucks/starbucks/starbucks18.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks18.jpg
#   inflating: /content/starbucks/starbucks/starbucks30.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks30.jpg
#   inflating: /content/starbucks/starbucks/starbucks24.jpg
#   inflating: /content/starbucks/__MACOSX/starbucks/._starbucks24.jpg

# %%
data_root = '/content/starbucks/starbucks'

# %%
data_list = glob.glob(f'{data_root}/*.jpg') +  glob.glob(f'{data_root}/*.jpeg')
data_list
# Out:
# ['/content/starbucks/starbucks/starbucks28.jpg',
#  '/content/starbucks/starbucks/starbucks14.jpg',
#  '/content/starbucks/starbucks/starbucks22.jpg',
#  '/content/starbucks/starbucks/starbucks39.jpg',
#  '/content/starbucks/starbucks/starbucks38.jpg',
#  '/content/starbucks/starbucks/starbucks36.jpg',
#  '/content/starbucks/starbucks/starbucks33.jpg',
#  '/content/starbucks/starbucks/starbucks37.jpg',
#  '/content/starbucks/starbucks/starbucks20.jpg',
#  '/content/starbucks/starbucks/starbucks34.jpg',
#  '/content/starbucks/starbucks/starbucks15.jpg',
#  '/content/starbucks/starbucks/starbucks23.jpg',
#  '/content/starbucks/starbucks/starbucks26.jpg',
#  '/content/starbucks/starbucks/starbucks29.jpg',
#  '/content/starbucks/starbucks/starbucks19.jpg',
#  '/content/starbucks/starbucks/starbucks21.jpg',
#  '/content/starbucks/starbucks/starbucks13.jpg',
#  '/content/starbucks/starbucks/starbucks32.jpg',
#  '/content/starbucks/starbucks/starbucks40.jpg',
#  '/content/starbucks/starbucks/starbucks12.jpg',
#  '/content/starbucks/starbucks/starbucks11.jpg',
#  '/content/starbucks/starbucks/starbucks30.jpg',
#  '/content/starbucks/starbucks/starbucks35.jpg',
#  '/content/starbucks/starbucks/starbucks31.jpg',
#  '/content/starbucks/starbucks/starbucks18.jpg',
#  '/content/starbucks/starbucks/starbucks25.jpg',
#  '/content/starbucks/starbucks/starbucks24.jpg',
#  '/content/starbucks/starbucks/starbucks16.jpg',
#  '/content/starbucks/starbucks/starbucks27.jpg',
#  '/content/starbucks/starbucks/starbucks17.jpg']

# %%
def load_coco_annotations(json_path):
    with open(json_path, 'r') as f:
      data = json.load(f)
    return data

# %%
load_coco_annotations(f'{data_root}/instances_default.json')
# Out:
# {'licenses': [{'name': '', 'id': 0, 'url': ''}],
#  'info': {'contributor': '',
#   'date_created': '',
#   'description': '',
#   'url': '',
#   'version': '',
#   'year': ''},
#  'categories': [{'id': 1, 'name': 'logo', 'supercategory': ''},
#   {'id': 2, 'name': 'text', 'supercategory': ''}],
#  'images': [{'id': 1,
#    'width': 236,
#    'height': 214,
#    'file_name': 'starbucks11.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 2,
#    'width': 201,
#    'height': 251,
#    'file_name': 'starbucks12.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 3,
#    'width': 395,
#    'height': 128,
#    'file_name': 'starbucks13.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 4,
#    'width': 301,
#    'height': 167,
#    'file_name': 'starbucks14.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 5,
#    'width': 275,
#    'height': 183,
#    'file_name': 'starbucks15.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 6,
#    'width': 299,
#    'height': 168,
#    'file_name': 'starbucks16.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 7,
#    'width': 275,
#    'height': 183,
#    'file_name': 'starbucks17.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 8,
#    'width': 276,
#    'height': 183,
#    'file_name': 'starbucks18.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 9,
#    'width': 275,
#    'height': 183,
#    'file_name': 'starbucks19.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 10,
#    'width': 259,
#    'height': 194,
#    'file_name': 'starbucks20.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 11,
#    'width': 259,
#    'height': 194,
#    'file_name': 'starbucks21.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 12,
#    'width': 259,
#    'height': 194,
#    'file_name': 'starbucks22.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 13,
#    'width': 225,
#    'height': 225,
#    'file_name': 'starbucks23.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 14,
#    'width': 300,
#    'height': 168,
#    'file_name': 'starbucks24.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 15,
#    'width': 280,
#    'height': 180,
#    'file_name': 'starbucks25.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 16,
#    'width': 275,
#    'height': 183,
#    'file_name': 'starbucks26.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 17,
#    'width': 275,
#    'height': 183,
#    'file_name': 'starbucks27.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 18,
#    'width': 225,
#    'height': 225,
#    'file_name': 'starbucks28.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 19,
#    'width': 225,
#    'height': 225,
#    'file_name': 'starbucks29.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 20,
#    'width': 318,
#    'height': 159,
#    'file_name': 'starbucks30.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 21,
#    'width': 264,
#    'height': 191,
#    'file_name': 'starbucks31.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 22,
#    'width': 259,
#    'height': 194,
#    'file_name': 'starbucks32.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 23,
#    'width': 225,
#    'height': 225,
#    'file_name': 'starbucks33.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 24,
#    'width': 275,
#    'height': 183,
#    'file_name': 'starbucks34.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 25,
#    'width': 259,
#    'height': 194,
#    'file_name': 'starbucks35.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 26,
#    'width': 190,
#    'height': 265,
#    'file_name': 'starbucks36.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 27,
#    'width': 275,
#    'height': 183,
#    'file_name': 'starbucks37.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 28,
#    'width': 298,
#    'height': 169,
#    'file_name': 'starbucks38.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 29,
#    'width': 225,
#    'height': 225,
#    'file_name': 'starbucks39.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0},
#   {'id': 30,
#    'width': 275,
#    'height': 183,
#    'file_name': 'starbucks40.jpg',
#    'license': 0,
#    'flickr_url': '',
#    'coco_url': '',
#    'date_captured': 0}],
#  'annotations': [{'id': 1,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': {'counts': [10781,
#      18,
#      191,
#      29,
#      181,
#      36,
#      175,
#      43,
#      168,
#      49,
#      163,
#      52,
#      1,
#      1,
#      158,
#      57,
#      154,
#      61,
#      152,
#      64,
#      147,
#      68,
#      145,
#      71,
#      141,
#      74,
#      139,
#      77,
#      137,
#      78,
#      134,
#      82,
#      130,
#      85,
#      128,
#      87,
#      127,
#      87,
#      126,
#      90,
#      122,
#      93,
#      121,
#      93,
#      120,
#      96,
#      117,
#      98,
#      115,
#      99,
#      114,
#      101,
#      113,
#      102,
#      111,
#      104,
#      109,
#      105,
#      109,
#      106,
#      107,
#      108,
#      105,
#      110,
#      104,
#      110,
#      103,
#      112,
#      102,
#      112,
#      101,
#      114,
#      100,
#      114,
#      99,
#      116,
#      98,
#      116,
#      97,
#      118,
#      96,
#      118,
#      95,
#      119,
#      95,
#      120,
#      94,
#      120,
#      93,
#      122,
#      92,
#      122,
#      92,
#      123,
#      90,
#      123,
#      91,
#      123,
#      91,
#      124,
#      90,
#      124,
#      90,
#      124,
#      89,
#      125,
#      89,
#      125,
#      89,
#      126,
#      88,
#      126,
#      87,
#      127,
#      87,
#      127,
#      87,
#      127,
#      87,
#      127,
#      87,
#      127,
#      87,
#      127,
#      87,
#      127,
#      87,
#      127,
#      87,
#      127,
#      87,
#      127,
#      1,
#      1,
#      85,
#      127,
#      1,
#      1,
#      85,
#      127,
#      1,
#      1,
#      85,
#      127,
#      87,
#      127,
#      1,
#      1,
#      85,
#      127,
#      87,
#      127,
#      87,
#      127,
#      88,
#      126,
#      88,
#      125,
#      89,
#      125,
#      89,
#      126,
#      88,
#      125,
#      89,
#      125,
#      90,
#      124,
#      90,
#      125,
#      89,
#      124,
#      90,
#      124,
#      91,
#      122,
#      92,
#      123,
#      91,
#      123,
#      92,
#      121,
#      93,
#      122,
#      92,
#      122,
#      93,
#      119,
#      95,
#      118,
#      97,
#      117,
#      97,
#      117,
#      98,
#      115,
#      99,
#      114,
#      100,
#      114,
#      101,
#      112,
#      103,
#      110,
#      104,
#      110,
#      105,
#      109,
#      106,
#      107,
#      108,
#      104,
#      110,
#      105,
#      110,
#      103,
#      1,
#      1,
#      110,
#      100,
#      115,
#      98,
#      116,
#      98,
#      117,
#      96,
#      119,
#      94,
#      121,
#      92,
#      123,
#      91,
#      124,
#      88,
#      127,
#      85,
#      130,
#      84,
#      131,
#      82,
#      134,
#      78,
#      137,
#      76,
#      139,
#      74,
#      142,
#      70,
#      145,
#      67,
#      149,
#      64,
#      152,
#      61,
#      155,
#      56,
#      160,
#      52,
#      164,
#      49,
#      168,
#      43,
#      174,
#      36,
#      182,
#      29,
#      189,
#      21,
#      206,
#      1,
#      12318],
#     'size': [214, 236]},
#    'area': 12905.0,
#    'bbox': [50.0, 26.0, 129.0, 129.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 2,
#    'image_id': 1,
#    'category_id': 2,
#    'segmentation': {'counts': [5738,
#      5,
#      3,
#      4,
#      200,
#      15,
#      198,
#      17,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      19,
#      195,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      17,
#      197,
#      17,
#      198,
#      15,
#      199,
#      11,
#      1,
#      1,
#      200,
#      11,
#      203,
#      11,
#      203,
#      12,
#      202,
#      14,
#      200,
#      16,
#      198,
#      17,
#      197,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      17,
#      197,
#      17,
#      197,
#      14,
#      2,
#      1,
#      197,
#      14,
#      200,
#      9,
#      1,
#      4,
#      201,
#      7,
#      2,
#      4,
#      1,
#      2,
#      200,
#      4,
#      1,
#      1,
#      1,
#      8,
#      199,
#      15,
#      198,
#      16,
#      198,
#      16,
#      197,
#      17,
#      197,
#      17,
#      196,
#      17,
#      197,
#      17,
#      197,
#      17,
#      197,
#      16,
#      198,
#      16,
#      198,
#      17,
#      197,
#      17,
#      197,
#      17,
#      198,
#      17,
#      198,
#      16,
#      200,
#      14,
#      202,
#      12,
#      205,
#      9,
#      207,
#      7,
#      204,
#      1,
#      1,
#      7,
#      204,
#      10,
#      202,
#      12,
#      198,
#      16,
#      197,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      17,
#      197,
#      17,
#      197,
#      17,
#      197,
#      18,
#      196,
#      18,
#      196,
#      18,
#      197,
#      17,
#      197,
#      17,
#      198,
#      16,
#      198,
#      16,
#      199,
#      14,
#      202,
#      3,
#      1,
#      8,
#      203,
#      10,
#      205,
#      6,
#      1,
#      2,
#      199,
#      16,
#      197,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      197,
#      16,
#      198,
#      16,
#      199,
#      15,
#      200,
#      13,
#      201,
#      12,
#      202,
#      12,
#      200,
#      14,
#      200,
#      14,
#      199,
#      16,
#      198,
#      17,
#      197,
#      17,
#      197,
#      18,
#      196,
#      18,
#      196,
#      18,
#      197,
#      17,
#      197,
#      17,
#      197,
#      17,
#      197,
#      17,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      17,
#      197,
#      17,
#      197,
#      16,
#      198,
#      15,
#      201,
#      12,
#      203,
#      11,
#      203,
#      11,
#      203,
#      12,
#      202,
#      12,
#      201,
#      14,
#      199,
#      16,
#      198,
#      16,
#      197,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      197,
#      17,
#      197,
#      16,
#      198,
#      16,
#      199,
#      15,
#      199,
#      14,
#      199,
#      16,
#      197,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      17,
#      197,
#      17,
#      197,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      197,
#      16,
#      199,
#      15,
#      199,
#      15,
#      199,
#      15,
#      198,
#      17,
#      197,
#      17,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      18,
#      196,
#      17,
#      198,
#      16,
#      199,
#      3,
#      3,
#      8,
#      208,
#      3,
#      7093],
#     'size': [214, 236]},
#    'area': 2853.0,
#    'bbox': [26.0, 170.0, 177.0, 19.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 3,
#    'image_id': 2,
#    'category_id': 1,
#    'segmentation': {'counts': [28659,
#      4,
#      244,
#      10,
#      240,
#      12,
#      238,
#      14,
#      236,
#      16,
#      234,
#      17,
#      234,
#      17,
#      234,
#      17,
#      233,
#      19,
#      232,
#      19,
#      232,
#      19,
#      233,
#      17,
#      234,
#      17,
#      234,
#      17,
#      234,
#      17,
#      235,
#      15,
#      237,
#      13,
#      239,
#      11,
#      244,
#      4,
#      17270],
#     'size': [251, 201]},
#    'area': 275.0,
#    'bbox': [114.0, 37.0, 19.0, 19.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 4,
#    'image_id': 2,
#    'category_id': 1,
#    'segmentation': {'counts': [16683,
#      7,
#      242,
#      11,
#      239,
#      13,
#      237,
#      15,
#      235,
#      17,
#      233,
#      19,
#      232,
#      19,
#      231,
#      21,
#      230,
#      21,
#      230,
#      21,
#      230,
#      21,
#      230,
#      21,
#      230,
#      21,
#      230,
#      21,
#      231,
#      19,
#      233,
#      17,
#      234,
#      17,
#      235,
#      15,
#      237,
#      13,
#      239,
#      11,
#      242,
#      7,
#      28741],
#     'size': [251, 201]},
#    'area': 347.0,
#    'bbox': [66.0, 110.0, 21.0, 21.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 5,
#    'image_id': 2,
#    'category_id': 1,
#    'segmentation': {'counts': [16759,
#      7,
#      242,
#      11,
#      239,
#      13,
#      237,
#      15,
#      235,
#      17,
#      233,
#      19,
#      232,
#      19,
#      231,
#      21,
#      230,
#      21,
#      230,
#      21,
#      230,
#      21,
#      230,
#      21,
#      230,
#      21,
#      230,
#      21,
#      231,
#      19,
#      233,
#      17,
#      234,
#      17,
#      235,
#      15,
#      237,
#      13,
#      239,
#      11,
#      242,
#      7,
#      28665],
#     'size': [251, 201]},
#    'area': 347.0,
#    'bbox': [66.0, 186.0, 21.0, 21.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 6,
#    'image_id': 3,
#    'category_id': 2,
#    'segmentation': {'counts': [15140,
#      9,
#      119,
#      10,
#      117,
#      11,
#      117,
#      11,
#      117,
#      11,
#      116,
#      13,
#      1,
#      1,
#      113,
#      13,
#      1,
#      1,
#      113,
#      13,
#      1,
#      1,
#      113,
#      17,
#      110,
#      20,
#      108,
#      21,
#      107,
#      22,
#      106,
#      22,
#      106,
#      22,
#      106,
#      22,
#      105,
#      23,
#      105,
#      23,
#      105,
#      22,
#      106,
#      22,
#      106,
#      22,
#      106,
#      22,
#      106,
#      22,
#      106,
#      21,
#      106,
#      22,
#      106,
#      22,
#      106,
#      22,
#      106,
#      22,
#      106,
#      22,
#      105,
#      23,
#      105,
#      23,
#      105,
#      23,
#      105,
#      22,
#      106,
#      22,
#      105,
#      23,
#      105,
#      23,
#      105,
#      23,
#      105,
#      23,
#      105,
#      23,
#      105,
#      22,
#      106,
#      22,
#      105,
#      15,
#      113,
#      14,
#      114,
#      13,
#      115,
#      13,
#      115,
#      13,
#      115,
#      13,
#      115,
#      13,
#      115,
#      13,
#      115,
#      12,
#      116,
#      12,
#      122,
#      4,
#      29018],
#     'size': [128, 395]},
#    'area': 934.0,
#    'bbox': [118.0, 28.0, 51.0, 27.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 7,
#    'image_id': 3,
#    'category_id': 2,
#    'segmentation': {'counts': [27291,
#      11,
#      116,
#      13,
#      115,
#      13,
#      115,
#      13,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      13,
#      115,
#      13,
#      115,
#      13,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      13,
#      115,
#      13,
#      115,
#      13,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      117,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      117,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      117,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      117,
#      11,
#      117,
#      11,
#      117,
#      12,
#      116,
#      12,
#      116,
#      12,
#      116,
#      12,
#      117,
#      11,
#      117,
#      11,
#      117,
#      11,
#      117,
#      11,
#      117,
#      12,
#      116,
#      12,
#      116,
#      12,
#      117,
#      11,
#      117,
#      11,
#      117,
#      11,
#      117,
#      11,
#      117,
#      12,
#      116,
#      12,
#      117,
#      11,
#      117,
#      11,
#      117,
#      11,
#      117,
#      11,
#      117,
#      11,
#      117,
#      11,
#      117,
#      12,
#      117,
#      11,
#      117,
#      11,
#      117,
#      11,
#      117,
#      11,
#      117,
#      11,
#      118,
#      10,
#      118,
#      10,
#      119,
#      9,
#      119,
#      9,
#      121,
#      1,
#      1,
#      4,
#      12881],
#     'size': [128, 395]},
#    'area': 954.0,
#    'bbox': [213.0, 26.0, 82.0, 22.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 8,
#    'image_id': 4,
#    'category_id': 2,
#    'segmentation': {'counts': [30287,
#      9,
#      157,
#      12,
#      155,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      14,
#      153,
#      14,
#      153,
#      14,
#      153,
#      14,
#      153,
#      14,
#      153,
#      14,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      154,
#      13,
#      155,
#      12,
#      155,
#      12,
#      155,
#      11,
#      157,
#      10,
#      14290],
#     'size': [167, 301]},
#    'area': 449.0,
#    'bbox': [181.0, 59.0, 35.0, 14.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 9,
#    'image_id': 4,
#    'category_id': 2,
#    'segmentation': {'counts': [15430,
#      4,
#      162,
#      5,
#      162,
#      6,
#      161,
#      6,
#      160,
#      7,
#      160,
#      8,
#      159,
#      9,
#      158,
#      11,
#      156,
#      11,
#      155,
#      11,
#      156,
#      11,
#      156,
#      11,
#      156,
#      11,
#      156,
#      11,
#      156,
#      6,
#      161,
#      6,
#      161,
#      4,
#      32164],
#     'size': [167, 301]},
#    'area': 138.0,
#    'bbox': [92.0, 63.0, 17.0, 12.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 10,
#    'image_id': 5,
#    'category_id': 1,
#    'segmentation': {'counts': [20010,
#      15,
#      163,
#      26,
#      152,
#      35,
#      145,
#      41,
#      140,
#      45,
#      136,
#      49,
#      131,
#      54,
#      128,
#      57,
#      124,
#      61,
#      121,
#      64,
#      118,
#      66,
#      115,
#      69,
#      112,
#      72,
#      110,
#      75,
#      107,
#      77,
#      105,
#      79,
#      103,
#      81,
#      101,
#      83,
#      99,
#      85,
#      97,
#      87,
#      96,
#      87,
#      95,
#      89,
#      93,
#      91,
#      92,
#      91,
#      91,
#      93,
#      90,
#      93,
#      89,
#      95,
#      87,
#      97,
#      86,
#      97,
#      85,
#      99,
#      84,
#      99,
#      84,
#      99,
#      83,
#      101,
#      82,
#      101,
#      82,
#      101,
#      81,
#      103,
#      80,
#      103,
#      80,
#      103,
#      80,
#      103,
#      79,
#      105,
#      78,
#      105,
#      78,
#      105,
#      78,
#      105,
#      78,
#      105,
#      78,
#      105,
#      78,
#      105,
#      78,
#      105,
#      78,
#      105,
#      78,
#      105,
#      78,
#      105,
#      78,
#      105,
#      79,
#      103,
#      80,
#      103,
#      80,
#      103,
#      80,
#      103,
#      80,
#      103,
#      81,
#      101,
#      82,
#      101,
#      82,
#      101,
#      83,
#      99,
#      84,
#      99,
#      85,
#      97,
#      86,
#      97,
#      87,
#      95,
#      88,
#      95,
#      88,
#      95,
#      89,
#      93,
#      91,
#      91,
#      92,
#      91,
#      93,
#      89,
#      94,
#      89,
#      95,
#      87,
#      97,
#      85,
#      99,
#      83,
#      101,
#      81,
#      103,
#      79,
#      105,
#      77,
#      107,
#      75,
#      109,
#      72,
#      113,
#      69,
#      116,
#      66,
#      118,
#      64,
#      120,
#      61,
#      124,
#      57,
#      127,
#      54,
#      132,
#      49,
#      136,
#      45,
#      140,
#      41,
#      145,
#      35,
#      153,
#      26,
#      162,
#      15,
#      13830],
#     'size': [183, 275]},
#    'area': 7495.0,
#    'bbox': [109.0, 18.0, 91.0, 105.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 11,
#    'image_id': 5,
#    'category_id': 2,
#    'segmentation': {'counts': [17520,
#      8,
#      174,
#      10,
#      171,
#      12,
#      170,
#      14,
#      168,
#      16,
#      165,
#      18,
#      165,
#      18,
#      165,
#      19,
#      164,
#      19,
#      164,
#      19,
#      164,
#      19,
#      164,
#      16,
#      1,
#      2,
#      164,
#      16,
#      167,
#      16,
#      167,
#      16,
#      168,
#      15,
#      168,
#      15,
#      168,
#      14,
#      169,
#      14,
#      169,
#      14,
#      169,
#      14,
#      170,
#      13,
#      170,
#      14,
#      169,
#      13,
#      170,
#      13,
#      170,
#      13,
#      170,
#      14,
#      169,
#      14,
#      169,
#      14,
#      169,
#      14,
#      169,
#      14,
#      169,
#      14,
#      169,
#      14,
#      169,
#      14,
#      169,
#      15,
#      168,
#      15,
#      168,
#      15,
#      168,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      168,
#      16,
#      167,
#      16,
#      168,
#      15,
#      167,
#      16,
#      167,
#      16,
#      168,
#      16,
#      167,
#      16,
#      168,
#      15,
#      167,
#      17,
#      165,
#      18,
#      166,
#      17,
#      166,
#      17,
#      166,
#      17,
#      166,
#      1,
#      1,
#      15,
#      166,
#      1,
#      1,
#      15,
#      166,
#      1,
#      1,
#      15,
#      168,
#      15,
#      168,
#      15,
#      168,
#      15,
#      169,
#      14,
#      168,
#      15,
#      165,
#      20,
#      163,
#      20,
#      163,
#      21,
#      162,
#      21,
#      163,
#      1,
#      1,
#      18,
#      165,
#      18,
#      165,
#      18,
#      165,
#      18,
#      165,
#      18,
#      165,
#      18,
#      165,
#      18,
#      166,
#      16,
#      166,
#      16,
#      165,
#      1,
#      1,
#      2,
#      1,
#      13,
#      166,
#      18,
#      167,
#      1,
#      1,
#      16,
#      167,
#      17,
#      166,
#      18,
#      165,
#      18,
#      167,
#      17,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      168,
#      15,
#      168,
#      16,
#      168,
#      14,
#      169,
#      15,
#      168,
#      15,
#      168,
#      15,
#      168,
#      15,
#      168,
#      16,
#      167,
#      16,
#      167,
#      16,
#      168,
#      15,
#      169,
#      14,
#      169,
#      14,
#      168,
#      16,
#      167,
#      16,
#      168,
#      15,
#      168,
#      6,
#      1,
#      8,
#      168,
#      5,
#      2,
#      8,
#      172,
#      1,
#      5,
#      5,
#      178,
#      1,
#      1,
#      2,
#      354,
#      13,
#      169,
#      15,
#      168,
#      15,
#      168,
#      15,
#      168,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      17,
#      166,
#      16,
#      168,
#      15,
#      168,
#      15,
#      169,
#      13,
#      171,
#      2,
#      4,
#      1,
#      1,
#      2,
#      9907],
#     'size': [183, 275]},
#    'area': 1933.0,
#    'bbox': [95.0, 128.0, 126.0, 34.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 12,
#    'image_id': 6,
#    'category_id': 1,
#    'segmentation': {'counts': [23120,
#      9,
#      156,
#      15,
#      151,
#      20,
#      146,
#      24,
#      143,
#      25,
#      141,
#      28,
#      139,
#      31,
#      136,
#      33,
#      135,
#      33,
#      134,
#      35,
#      132,
#      37,
#      131,
#      37,
#      130,
#      39,
#      129,
#      39,
#      128,
#      41,
#      127,
#      41,
#      127,
#      41,
#      126,
#      43,
#      125,
#      43,
#      125,
#      43,
#      125,
#      43,
#      125,
#      43,
#      125,
#      43,
#      125,
#      43,
#      125,
#      43,
#      125,
#      43,
#      126,
#      41,
#      127,
#      41,
#      127,
#      41,
#      128,
#      39,
#      129,
#      39,
#      129,
#      39,
#      130,
#      37,
#      131,
#      37,
#      133,
#      33,
#      136,
#      31,
#      137,
#      31,
#      138,
#      28,
#      142,
#      25,
#      144,
#      24,
#      146,
#      20,
#      150,
#      15,
#      156,
#      9,
#      20047],
#     'size': [168, 299]},
#    'area': 1445.0,
#    'bbox': [137.0, 87.0, 43.0, 43.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 13,
#    'image_id': 6,
#    'category_id': 2,
#    'segmentation': [],
#    'area': 4844.280000000001,
#    'bbox': [16.01, 9.82, 173.01, 28.0],
#    'iscrowd': 0,
#    'attributes': {'occluded': False, 'rotation': 0.0}},
#   {'id': 14,
#    'image_id': 7,
#    'category_id': 2,
#    'segmentation': {'counts': [10309,
#      4,
#      178,
#      6,
#      176,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      176,
#      7,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      176,
#      7,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      176,
#      7,
#      175,
#      8,
#      176,
#      7,
#      176,
#      7,
#      176,
#      7,
#      176,
#      7,
#      176,
#      6,
#      177,
#      7,
#      176,
#      7,
#      176,
#      7,
#      176,
#      7,
#      176,
#      7,
#      176,
#      7,
#      176,
#      7,
#      175,
#      8,
#      176,
#      7,
#      176,
#      7,
#      176,
#      7,
#      176,
#      7,
#      176,
#      6,
#      21345],
#     'size': [183, 275]},
#    'area': 796.0,
#    'bbox': [56.0, 59.0, 103.0, 8.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 15,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': {'counts': [32086,
#      6,
#      174,
#      11,
#      171,
#      14,
#      168,
#      15,
#      166,
#      19,
#      163,
#      21,
#      161,
#      23,
#      160,
#      23,
#      160,
#      23,
#      159,
#      25,
#      158,
#      25,
#      157,
#      27,
#      156,
#      27,
#      156,
#      27,
#      156,
#      27,
#      156,
#      27,
#      156,
#      27,
#      156,
#      27,
#      156,
#      27,
#      156,
#      27,
#      157,
#      25,
#      158,
#      25,
#      159,
#      23,
#      160,
#      23,
#      160,
#      23,
#      161,
#      21,
#      163,
#      19,
#      166,
#      15,
#      169,
#      14,
#      170,
#      11,
#      175,
#      6,
#      12743],
#     'size': [183, 275]},
#    'area': 653.0,
#    'bbox': [175.0, 50.0, 31.0, 27.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 16,
#    'image_id': 8,
#    'category_id': 1,
#    'segmentation': {'counts': [30482,
#      9,
#      171,
#      16,
#      164,
#      21,
#      161,
#      23,
#      158,
#      27,
#      155,
#      29,
#      153,
#      31,
#      151,
#      33,
#      150,
#      33,
#      149,
#      35,
#      147,
#      37,
#      145,
#      39,
#      144,
#      39,
#      144,
#      39,
#      143,
#      41,
#      142,
#      41,
#      142,
#      41,
#      142,
#      41,
#      142,
#      41,
#      142,
#      41,
#      142,
#      41,
#      142,
#      41,
#      143,
#      39,
#      144,
#      39,
#      144,
#      39,
#      145,
#      37,
#      146,
#      37,
#      146,
#      37,
#      147,
#      35,
#      149,
#      33,
#      151,
#      31,
#      153,
#      29,
#      155,
#      27,
#      158,
#      23,
#      161,
#      21,
#      165,
#      16,
#      170,
#      9,
#      13429],
#     'size': [183, 276]},
#    'area': 1191.0,
#    'bbox': [166.0, 88.0, 37.0, 41.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 17,
#    'image_id': 8,
#    'category_id': 2,
#    'segmentation': {'counts': [586,
#      1,
#      547,
#      2,
#      181,
#      3,
#      180,
#      3,
#      1,
#      1,
#      178,
#      3,
#      180,
#      4,
#      179,
#      5,
#      177,
#      6,
#      177,
#      6,
#      177,
#      6,
#      178,
#      5,
#      178,
#      6,
#      177,
#      5,
#      178,
#      5,
#      178,
#      5,
#      177,
#      6,
#      177,
#      6,
#      2,
#      1,
#      174,
#      6,
#      2,
#      1,
#      174,
#      7,
#      1,
#      1,
#      175,
#      11,
#      172,
#      13,
#      169,
#      14,
#      169,
#      15,
#      168,
#      15,
#      168,
#      16,
#      167,
#      15,
#      168,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      15,
#      168,
#      16,
#      168,
#      15,
#      168,
#      15,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      166,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      166,
#      17,
#      166,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      15,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      166,
#      17,
#      166,
#      17,
#      166,
#      17,
#      166,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      16,
#      167,
#      15,
#      168,
#      15,
#      168,
#      15,
#      168,
#      15,
#      168,
#      15,
#      168,
#      14,
#      169,
#      14,
#      169,
#      15,
#      168,
#      14,
#      169,
#      14,
#      169,
#      14,
#      169,
#      14,
#      169,
#      15,
#      168,
#      14,
#      169,
#      13,
#      162,
#      1,
#      7,
#      13,
#      170,
#      13,
#      170,
#      11,
#      172,
#      11,
#      173,
#      10,
#      173,
#      10,
#      1,
#      1,
#      171,
#      10,
#      173,
#      11,
#      172,
#      11,
#      172,
#      12,
#      170,
#      12,
#      172,
#      10,
#      174,
#      8,
#      176,
#      7,
#      177,
#      6,
#      727,
#      1,
#      1,
#      2,
#      179,
#      1,
#      32171],
#     'size': [183, 276]},
#    'area': 1130.0,
#    'bbox': [3.0, 23.0, 98.0, 28.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 18,
#    'image_id': 9,
#    'category_id': 2,
#    'segmentation': {'counts': [14877,
#      2,
#      1,
#      1,
#      177,
#      7,
#      176,
#      8,
#      174,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      174,
#      9,
#      174,
#      9,
#      174,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      8,
#      175,
#      9,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      174,
#      9,
#      174,
#      9,
#      173,
#      10,
#      173,
#      10,
#      173,
#      10,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      174,
#      9,
#      175,
#      8,
#      731,
#      1,
#      365,
#      1,
#      182,
#      1,
#      181,
#      1,
#      549,
#      1,
#      181,
#      1,
#      731,
#      1,
#      914,
#      1,
#      731,
#      1,
#      731,
#      1,
#      183,
#      1,
#      547,
#      2,
#      182,
#      1,
#      182,
#      1,
#      365,
#      1,
#      182,
#      1,
#      182,
#      1,
#      365,
#      1,
#      181,
#      3,
#      181,
#      1,
#      365,
#      1,
#      182,
#      1,
#      182,
#      1,
#      182,
#      1,
#      182,
#      1,
#      182,
#      1,
#      182,
#      1,
#      3782],
#     'size': [183, 275]},
#    'area': 1216.0,
#    'bbox': [81.0, 51.0, 174.0, 11.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 19,
#    'image_id': 10,
#    'category_id': 2,
#    'segmentation': {'counts': [15759,
#      6,
#      187,
#      8,
#      186,
#      9,
#      184,
#      10,
#      184,
#      10,
#      185,
#      9,
#      185,
#      9,
#      185,
#      9,
#      185,
#      9,
#      185,
#      9,
#      185,
#      9,
#      186,
#      9,
#      185,
#      9,
#      185,
#      9,
#      2,
#      7,
#      176,
#      19,
#      175,
#      20,
#      174,
#      20,
#      175,
#      19,
#      175,
#      19,
#      175,
#      19,
#      175,
#      19,
#      175,
#      19,
#      175,
#      19,
#      176,
#      19,
#      175,
#      19,
#      175,
#      19,
#      175,
#      19,
#      175,
#      19,
#      175,
#      19,
#      175,
#      19,
#      175,
#      19,
#      176,
#      18,
#      176,
#      18,
#      176,
#      18,
#      176,
#      18,
#      176,
#      18,
#      176,
#      19,
#      175,
#      19,
#      176,
#      18,
#      176,
#      18,
#      176,
#      18,
#      176,
#      18,
#      176,
#      18,
#      176,
#      19,
#      175,
#      19,
#      175,
#      19,
#      175,
#      19,
#      176,
#      18,
#      176,
#      18,
#      176,
#      18,
#      176,
#      18,
#      176,
#      18,
#      177,
#      16,
#      178,
#      8,
#      2,
#      4,
#      180,
#      8,
#      186,
#      8,
#      186,
#      8,
#      186,
#      9,
#      185,
#      9,
#      186,
#      7,
#      187,
#      7,
#      187,
#      7,
#      189,
#      4,
#      22446],
#     'size': [194, 259]},
#    'area': 935.0,
#    'bbox': [81.0, 43.0, 63.0, 25.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 20,
#    'image_id': 10,
#    'category_id': 1,
#    'segmentation': {'counts': [8001,
#      7,
#      184,
#      12,
#      180,
#      17,
#      176,
#      19,
#      174,
#      21,
#      172,
#      23,
#      171,
#      23,
#      170,
#      25,
#      169,
#      25,
#      169,
#      25,
#      168,
#      27,
#      167,
#      27,
#      167,
#      27,
#      167,
#      27,
#      167,
#      27,
#      167,
#      27,
#      167,
#      27,
#      168,
#      25,
#      169,
#      25,
#      170,
#      23,
#      171,
#      23,
#      171,
#      23,
#      172,
#      21,
#      174,
#      19,
#      176,
#      17,
#      179,
#      12,
#      185,
#      7,
#      37194],
#     'size': [194, 259]},
#    'area': 581.0,
#    'bbox': [41.0, 37.0, 27.0, 27.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 21,
#    'image_id': 11,
#    'category_id': 1,
#    'segmentation': {'counts': [13319,
#      9,
#      181,
#      16,
#      177,
#      20,
#      172,
#      24,
#      169,
#      26,
#      166,
#      29,
#      164,
#      31,
#      162,
#      33,
#      160,
#      35,
#      159,
#      35,
#      158,
#      37,
#      156,
#      39,
#      155,
#      39,
#      154,
#      41,
#      153,
#      41,
#      153,
#      41,
#      152,
#      43,
#      151,
#      43,
#      151,
#      43,
#      151,
#      43,
#      151,
#      43,
#      151,
#      43,
#      151,
#      43,
#      151,
#      43,
#      152,
#      41,
#      153,
#      41,
#      153,
#      41,
#      153,
#      41,
#      154,
#      39,
#      156,
#      37,
#      157,
#      37,
#      157,
#      37,
#      159,
#      33,
#      161,
#      33,
#      162,
#      31,
#      164,
#      29,
#      167,
#      26,
#      169,
#      24,
#      172,
#      20,
#      175,
#      16,
#      182,
#      9,
#      29158],
#     'size': [194, 259]},
#    'area': 1375.0,
#    'bbox': [68.0, 110.0, 41.0, 43.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 22,
#    'image_id': 11,
#    'category_id': 1,
#    'segmentation': {'counts': [30192,
#      11,
#      180,
#      17,
#      174,
#      23,
#      169,
#      27,
#      166,
#      30,
#      162,
#      33,
#      160,
#      35,
#      158,
#      37,
#      156,
#      39,
#      154,
#      41,
#      152,
#      43,
#      151,
#      43,
#      150,
#      45,
#      148,
#      47,
#      147,
#      47,
#      147,
#      47,
#      147,
#      47,
#      146,
#      49,
#      145,
#      49,
#      145,
#      49,
#      145,
#      49,
#      145,
#      49,
#      145,
#      49,
#      145,
#      49,
#      146,
#      47,
#      147,
#      47,
#      147,
#      47,
#      147,
#      47,
#      148,
#      45,
#      150,
#      43,
#      151,
#      43,
#      152,
#      41,
#      154,
#      39,
#      156,
#      37,
#      158,
#      35,
#      160,
#      33,
#      163,
#      30,
#      165,
#      27,
#      169,
#      23,
#      174,
#      17,
#      180,
#      11,
#      12283],
#     'size': [194, 259]},
#    'area': 1567.0,
#    'bbox': [155.0, 103.0, 41.0, 49.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 23,
#    'image_id': 12,
#    'category_id': 1,
#    'segmentation': {'counts': [15414,
#      13,
#      175,
#      25,
#      166,
#      31,
#      161,
#      36,
#      155,
#      41,
#      151,
#      45,
#      147,
#      49,
#      143,
#      53,
#      140,
#      55,
#      137,
#      59,
#      134,
#      61,
#      132,
#      63,
#      130,
#      65,
#      128,
#      67,
#      126,
#      69,
#      124,
#      71,
#      122,
#      73,
#      120,
#      75,
#      118,
#      77,
#      116,
#      79,
#      114,
#      81,
#      112,
#      83,
#      111,
#      83,
#      110,
#      85,
#      109,
#      85,
#      108,
#      87,
#      107,
#      87,
#      106,
#      89,
#      105,
#      89,
#      104,
#      91,
#      102,
#      93,
#      101,
#      93,
#      100,
#      95,
#      99,
#      95,
#      99,
#      95,
#      99,
#      95,
#      98,
#      97,
#      97,
#      97,
#      97,
#      97,
#      96,
#      99,
#      95,
#      99,
#      95,
#      99,
#      95,
#      99,
#      95,
#      99,
#      95,
#      99,
#      94,
#      101,
#      93,
#      101,
#      93,
#      101,
#      93,
#      101,
#      93,
#      101,
#      93,
#      101,
#      93,
#      101,
#      93,
#      101,
#      93,
#      101,
#      93,
#      101,
#      93,
#      101,
#      93,
#      101,
#      93,
#      101,
#      94,
#      99,
#      95,
#      99,
#      95,
#      99,
#      95,
#      99,
#      95,
#      99,
#      95,
#      99,
#      96,
#      97,
#      97,
#      97,
#      97,
#      97,
#      98,
#      95,
#      99,
#      95,
#      99,
#      95,
#      100,
#      93,
#      101,
#      93,
#      102,
#      91,
#      103,
#      91,
#      103,
#      91,
#      104,
#      89,
#      105,
#      89,
#      106,
#      87,
#      107,
#      87,
#      108,
#      85,
#      110,
#      83,
#      112,
#      81,
#      114,
#      79,
#      115,
#      79,
#      116,
#      77,
#      118,
#      75,
#      119,
#      75,
#      120,
#      73,
#      123,
#      69,
#      126,
#      67,
#      128,
#      65,
#      130,
#      63,
#      132,
#      61,
#      134,
#      59,
#      137,
#      55,
#      140,
#      53,
#      143,
#      49,
#      147,
#      45,
#      151,
#      41,
#      156,
#      36,
#      160,
#      31,
#      166,
#      25,
#      175,
#      13,
#      15031],
#     'size': [194, 259]},
#    'area': 8151.0,
#    'bbox': [79.0, 44.0, 103.0, 101.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 24,
#    'image_id': 13,
#    'category_id': 1,
#    'segmentation': {'counts': [7079,
#      17,
#      201,
#      31,
#      190,
#      39,
#      182,
#      47,
#      176,
#      52,
#      169,
#      58,
#      165,
#      63,
#      160,
#      67,
#      156,
#      71,
#      152,
#      75,
#      148,
#      79,
#      144,
#      83,
#      141,
#      85,
#      138,
#      89,
#      135,
#      91,
#      133,
#      94,
#      129,
#      97,
#      127,
#      99,
#      125,
#      101,
#      122,
#      104,
#      120,
#      106,
#      118,
#      109,
#      115,
#      111,
#      113,
#      113,
#      111,
#      115,
#      109,
#      117,
#      107,
#      119,
#      106,
#      119,
#      105,
#      121,
#      103,
#      123,
#      101,
#      125,
#      99,
#      127,
#      97,
#      129,
#      95,
#      131,
#      94,
#      131,
#      93,
#      133,
#      92,
#      133,
#      91,
#      135,
#      90,
#      135,
#      89,
#      137,
#      87,
#      139,
#      86,
#      139,
#      85,
#      141,
#      84,
#      141,
#      83,
#      143,
#      81,
#      145,
#      80,
#      145,
#      79,
#      147,
#      78,
#      147,
#      78,
#      147,
#      77,
#      149,
#      76,
#      149,
#      75,
#      151,
#      74,
#      151,
#      74,
#      151,
#      73,
#      153,
#      72,
#      153,
#      72,
#      153,
#      71,
#      155,
#      70,
#      155,
#      70,
#      155,
#      70,
#      155,
#      69,
#      157,
#      68,
#      157,
#      68,
#      157,
#      68,
#      157,
#      67,
#      159,
#      66,
#      159,
#      66,
#      159,
#      66,
#      159,
#      66,
#      159,
#      66,
#      159,
#      66,
#      159,
#      65,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      64,
#      161,
#      65,
#      159,
#      66,
#      159,
#      66,
#      159,
#      66,
#      159,
#      66,
#      159,
#      66,
#      159,
#      66,
#      159,
#      67,
#      157,
#      68,
#      157,
#      68,
#      157,
#      68,
#      157,
#      69,
#      155,
#      70,
#      155,
#      70,
#      155,
#      70,
#      155,
#      71,
#      153,
#      72,
#      153,
#      72,
#      153,
#      73,
#      151,
#      74,
#      151,
#      74,
#      151,
#      75,
#      149,
#      76,
#      149,
#      76,
#      149,
#      77,
#      147,
#      78,
#      147,
#      79,
#      145,
#      80,
#      145,
#      81,
#      143,
#      83,
#      141,
#      84,
#      141,
#      85,
#      139,
#      86,
#      139,
#      86,
#      139,
#      87,
#      137,
#      89,
#      135,
#      90,
#      135,
#      91,
#      133,
#      93,
#      131,
#      94,
#      131,
#      95,
#      129,
#      97,
#      127,
#      99,
#      125,
#      101,
#      123,
#      103,
#      121,
#      105,
#      119,
#      106,
#      119,
#      107,
#      117,
#      109,
#      115,
#      111,
#      113,
#      113,
#      111,
#      115,
#      109,
#      117,
#      106,
#      120,
#      104,
#      123,
#      101,
#      125,
#      99,
#      127,
#      97,
#      130,
#      94,
#      132,
#      91,
#      135,
#      89,
#      138,
#      85,
#      141,
#      83,
#      144,
#      79,
#      148,
#      75,
#      152,
#      71,
#      156,
#      67,
#      160,
#      63,
#      164,
#      58,
#      171,
#      52,
#      175,
#      47,
#      182,
#      39,
#      190,
#      31,
#      201,
#      17,
#      7079],
#     'size': [225, 225]},
#    'area': 20577.0,
#    'bbox': [31.0, 32.0, 163.0, 161.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 25,
#    'image_id': 14,
#    'category_id': 2,
#    'segmentation': {'counts': [693,
#      9,
#      1,
#      2,
#      155,
#      16,
#      151,
#      18,
#      150,
#      19,
#      149,
#      19,
#      150,
#      18,
#      150,
#      18,
#      151,
#      18,
#      151,
#      18,
#      150,
#      18,
#      151,
#      18,
#      150,
#      18,
#      151,
#      17,
#      152,
#      17,
#      151,
#      18,
#      151,
#      17,
#      151,
#      18,
#      151,
#      17,
#      151,
#      18,
#      151,
#      17,
#      151,
#      18,
#      151,
#      17,
#      152,
#      17,
#      151,
#      17,
#      152,
#      17,
#      152,
#      16,
#      152,
#      17,
#      152,
#      16,
#      152,
#      16,
#      153,
#      16,
#      153,
#      15,
#      153,
#      16,
#      153,
#      15,
#      153,
#      16,
#      153,
#      15,
#      153,
#      16,
#      153,
#      15,
#      154,
#      15,
#      153,
#      15,
#      154,
#      15,
#      153,
#      15,
#      154,
#      15,
#      153,
#      15,
#      154,
#      15,
#      153,
#      15,
#      154,
#      14,
#      155,
#      14,
#      154,
#      14,
#      155,
#      14,
#      155,
#      13,
#      155,
#      14,
#      155,
#      14,
#      154,
#      14,
#      155,
#      13,
#      155,
#      14,
#      155,
#      13,
#      155,
#      13,
#      157,
#      12,
#      156,
#      12,
#      157,
#      12,
#      156,
#      12,
#      157,
#      12,
#      157,
#      11,
#      157,
#      12,
#      157,
#      11,
#      158,
#      10,
#      159,
#      8,
#      38575],
#     'size': [168, 300]},
#    'area': 1019.0,
#    'bbox': [4.0, 19.0, 67.0, 47.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 26,
#    'image_id': 14,
#    'category_id': 2,
#    'segmentation': {'counts': [9487,
#      4,
#      4,
#      4,
#      155,
#      13,
#      154,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      15,
#      153,
#      15,
#      154,
#      14,
#      154,
#      15,
#      153,
#      15,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      153,
#      15,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      153,
#      15,
#      153,
#      14,
#      154,
#      15,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      153,
#      14,
#      156,
#      12,
#      158,
#      8,
#      160,
#      7,
#      161,
#      7,
#      163,
#      1,
#      1,
#      3,
#      166,
#      1,
#      167,
#      2,
#      159,
#      9,
#      158,
#      11,
#      156,
#      13,
#      155,
#      14,
#      153,
#      15,
#      153,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      15,
#      153,
#      15,
#      153,
#      15,
#      154,
#      13,
#      155,
#      14,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      15,
#      153,
#      15,
#      153,
#      14,
#      155,
#      13,
#      158,
#      9,
#      159,
#      9,
#      156,
#      14,
#      154,
#      14,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      12,
#      1,
#      1,
#      154,
#      13,
#      155,
#      12,
#      156,
#      13,
#      155,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      14,
#      154,
#      14,
#      154,
#      15,
#      153,
#      15,
#      153,
#      15,
#      153,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      16,
#      152,
#      15,
#      155,
# ...
#      185,
#      9,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      9,
#      185,
#      9,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      9,
#      185,
#      9,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      9,
#      185,
#      9,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      183,
#      11,
#      183,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      9,
#      185,
#      9,
#      185,
#      9,
#      184,
#      11,
#      183,
#      11,
#      182,
#      11,
#      183,
#      11,
#      184,
#      10,
#      184,
#      10,
#      183,
#      11,
#      183,
#      11,
#      183,
#      11,
#      183,
#      11,
#      183,
#      11,
#      183,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      183,
#      11,
#      183,
#      11,
#      183,
#      11,
#      183,
#      10,
#      184,
#      10,
#      184,
#      10,
#      184,
#      10,
#      183,
#      11,
#      183,
#      11,
#      183,
#      11,
#      183,
#      11,
#      183,
#      10,
#      184,
#      11,
#      183,
#      11,
#      183,
#      11,
#      183,
#      10,
#      184,
#      10,
#      184,
#      10,
#      183,
#      11,
#      183,
#      11,
#      183,
#      11,
#      183,
#      11,
#      183,
#      11,
#      183,
#      10,
#      184,
#      10,
#      185,
#      9,
#      24952],
#     'size': [194, 259]},
#    'area': 1004.0,
#    'bbox': [30.0, 64.0, 101.0, 21.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 48,
#    'image_id': 25,
#    'category_id': 1,
#    'segmentation': {'counts': [22420,
#      4,
#      186,
#      11,
#      182,
#      13,
#      180,
#      15,
#      178,
#      17,
#      177,
#      17,
#      177,
#      17,
#      176,
#      19,
#      175,
#      19,
#      175,
#      19,
#      176,
#      17,
#      177,
#      17,
#      177,
#      17,
#      178,
#      15,
#      180,
#      13,
#      182,
#      11,
#      187,
#      4,
#      24718],
#     'size': [194, 259]},
#    'area': 245.0,
#    'bbox': [115.0, 102.0, 17.0, 19.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 49,
#    'image_id': 26,
#    'category_id': 2,
#    'segmentation': {'counts': [2400,
#      4,
#      5,
#      3,
#      250,
#      16,
#      248,
#      18,
#      247,
#      18,
#      246,
#      19,
#      246,
#      20,
#      245,
#      20,
#      245,
#      20,
#      245,
#      20,
#      245,
#      20,
#      245,
#      20,
#      245,
#      19,
#      246,
#      19,
#      246,
#      18,
#      248,
#      17,
#      248,
#      16,
#      249,
#      7,
#      1,
#      5,
#      251,
#      12,
#      253,
#      12,
#      253,
#      8,
#      3,
#      1,
#      253,
#      13,
#      252,
#      16,
#      249,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      18,
#      247,
#      17,
#      248,
#      8,
#      2,
#      6,
#      249,
#      16,
#      249,
#      15,
#      251,
#      5,
#      1,
#      12,
#      250,
#      15,
#      250,
#      15,
#      250,
#      16,
#      246,
#      19,
#      245,
#      19,
#      246,
#      19,
#      246,
#      18,
#      247,
#      18,
#      247,
#      18,
#      247,
#      18,
#      247,
#      18,
#      247,
#      18,
#      247,
#      19,
#      246,
#      19,
#      247,
#      18,
#      250,
#      15,
#      253,
#      12,
#      255,
#      10,
#      257,
#      8,
#      257,
#      7,
#      258,
#      7,
#      248,
#      17,
#      247,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      18,
#      247,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      247,
#      18,
#      248,
#      17,
#      249,
#      16,
#      249,
#      16,
#      249,
#      14,
#      251,
#      14,
#      249,
#      17,
#      247,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      20,
#      245,
#      19,
#      246,
#      20,
#      245,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      247,
#      17,
#      248,
#      17,
#      249,
#      14,
#      251,
#      13,
#      252,
#      12,
#      252,
#      14,
#      250,
#      16,
#      249,
#      17,
#      248,
#      18,
#      247,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      20,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      245,
#      20,
#      245,
#      20,
#      245,
#      19,
#      246,
#      19,
#      246,
#      18,
#      247,
#      18,
#      247,
#      17,
#      249,
#      15,
#      251,
#      13,
#      253,
#      12,
#      252,
#      14,
#      252,
#      13,
#      251,
#      15,
#      249,
#      17,
#      248,
#      18,
#      246,
#      19,
#      246,
#      20,
#      245,
#      20,
#      245,
#      20,
#      244,
#      21,
#      244,
#      21,
#      245,
#      20,
#      245,
#      20,
#      245,
#      20,
#      245,
#      19,
#      246,
#      19,
#      246,
#      18,
#      248,
#      17,
#      248,
#      17,
#      248,
#      17,
#      247,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      19,
#      246,
#      20,
#      245,
#      20,
#      245,
#      19,
#      246,
#      19,
#      246,
#      19,
#      247,
#      18,
#      248,
#      16,
#      247,
#      19,
#      247,
#      18,
#      246,
#      19,
#      246,
#      19,
#      246,
#      20,
#      245,
#      20,
#      245,
#      20,
#      245,
#      20,
#      245,
#      20,
#      245,
#      20,
#      245,
#      20,
#      245,
#      19,
#      246,
#      19,
#      247,
#      17,
#      249,
#      4,
#      1,
#      10,
#      258,
#      5,
#      2360],
#     'size': [265, 190]},
#    'area': 3035.0,
#    'bbox': [9.0, 9.0, 173.0, 21.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 50,
#    'image_id': 27,
#    'category_id': 1,
#    'segmentation': {'counts': [27724,
#      11,
#      168,
#      19,
#      162,
#      24,
#      157,
#      28,
#      152,
#      33,
#      149,
#      35,
#      146,
#      39,
#      143,
#      41,
#      141,
#      43,
#      140,
#      43,
#      139,
#      45,
#      137,
#      47,
#      135,
#      49,
#      134,
#      49,
#      133,
#      51,
#      131,
#      53,
#      130,
#      53,
#      129,
#      55,
#      128,
#      55,
#      127,
#      57,
#      126,
#      57,
#      126,
#      57,
#      125,
#      59,
#      124,
#      59,
#      124,
#      59,
#      124,
#      59,
#      124,
#      59,
#      124,
#      59,
#      124,
#      59,
#      124,
#      59,
#      124,
#      59,
#      124,
#      59,
#      124,
#      59,
#      125,
#      57,
#      126,
#      57,
#      126,
#      57,
#      127,
#      55,
#      128,
#      55,
#      129,
#      53,
#      130,
#      53,
#      131,
#      51,
#      132,
#      51,
#      133,
#      49,
#      135,
#      47,
#      137,
#      45,
#      139,
#      43,
#      140,
#      43,
#      141,
#      41,
#      143,
#      39,
#      146,
#      35,
#      149,
#      33,
#      153,
#      28,
#      157,
#      24,
#      161,
#      19,
#      168,
#      11,
#      12708],
#     'size': [183, 275]},
#    'area': 2539.0,
#    'bbox': [151.0, 67.0, 55.0, 59.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 51,
#    'image_id': 28,
#    'category_id': 1,
#    'segmentation': {'counts': [3408,
#      8,
#      158,
#      13,
#      154,
#      17,
#      151,
#      20,
#      147,
#      23,
#      146,
#      23,
#      145,
#      25,
#      143,
#      27,
#      142,
#      27,
#      141,
#      29,
#      140,
#      29,
#      140,
#      29,
#      139,
#      31,
#      138,
#      31,
#      138,
#      31,
#      138,
#      31,
#      138,
#      31,
#      138,
#      31,
#      138,
#      31,
#      138,
#      31,
#      139,
#      29,
#      140,
#      29,
#      141,
#      27,
#      142,
#      27,
#      143,
#      25,
#      144,
#      25,
#      145,
#      23,
#      148,
#      20,
#      150,
#      17,
#      154,
#      13,
#      159,
#      8,
#      41876],
#     'size': [169, 298]},
#    'area': 761.0,
#    'bbox': [20.0, 16.0, 31.0, 31.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 52,
#    'image_id': 28,
#    'category_id': 2,
#    'segmentation': {'counts': [9491,
#      11,
#      157,
#      13,
#      156,
#      13,
#      155,
#      14,
#      155,
#      14,
#      155,
#      15,
#      154,
#      14,
#      155,
#      14,
#      155,
#      14,
#      156,
#      13,
#      156,
#      13,
#      156,
#      12,
#      157,
#      12,
#      157,
#      12,
#      157,
#      11,
#      157,
#      13,
#      157,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      14,
#      155,
#      14,
#      156,
#      13,
#      156,
#      12,
#      157,
#      12,
#      157,
#      12,
#      157,
#      12,
#      156,
#      13,
#      156,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      156,
#      12,
#      157,
#      12,
#      157,
#      12,
#      156,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      13,
#      157,
#      12,
#      157,
#      12,
#      157,
#      12,
#      156,
#      13,
#      156,
#      13,
#      156,
#      14,
#      155,
#      14,
#      155,
#      14,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      155,
#      14,
#      155,
#      14,
#      156,
#      13,
#      156,
#      13,
#      156,
#      12,
#      157,
#      12,
#      157,
#      12,
#      157,
#      12,
#      157,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      14,
#      155,
#      13,
#      157,
#      12,
#      157,
#      11,
#      159,
#      8,
#      162,
#      7,
#      162,
#      8,
#      161,
#      8,
#      161,
#      8,
#      161,
#      8,
#      159,
#      11,
#      158,
#      12,
#      157,
#      12,
#      157,
#      13,
#      156,
#      13,
#      155,
#      14,
#      156,
#      13,
#      155,
#      14,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      12,
#      157,
#      11,
#      158,
#      12,
#      157,
#      12,
#      157,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      12,
#      159,
#      9,
#      160,
#      8,
#      159,
#      13,
#      157,
#      11,
#      157,
#      10,
#      1,
#      2,
#      157,
#      7,
#      1,
#      2,
#      158,
#      13,
#      156,
#      13,
#      156,
#      12,
#      157,
#      11,
#      158,
#      10,
#      159,
#      10,
#      159,
#      10,
#      159,
#      10,
#      160,
#      7,
#      163,
#      2,
#      165,
#      13,
#      157,
#      11,
#      158,
#      11,
#      158,
#      11,
#      158,
#      12,
#      156,
#      13,
#      156,
#      10,
#      159,
#      1,
#      1,
#      8,
#      159,
#      10,
#      159,
#      10,
#      159,
#      10,
#      159,
#      12,
#      157,
#      13,
#      157,
#      9,
#      159,
#      14,
#      156,
#      13,
#      156,
#      9,
#      1,
#      3,
#      156,
#      10,
#      2,
#      1,
#      156,
#      11,
#      1,
#      1,
#      156,
#      13,
#      156,
#      11,
#      1,
#      1,
#      158,
#      7,
#      3,
#      1,
#      156,
#      11,
#      158,
#      13,
#      156,
#      12,
#      157,
#      13,
#      156,
#      13,
#      157,
#      10,
#      1,
#      1,
#      156,
#      13,
#      156,
#      13,
#      156,
#      13,
#      156,
#      11,
#      1,
#      1,
#      156,
#      11,
#      1,
#      1,
#      156,
#      13,
#      156,
#      11,
#      1,
#      1,
#      157,
#      6,
#      5034],
#     'size': [169, 298]},
#    'area': 2654.0,
#    'bbox': [56.0, 25.0, 213.0, 17.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 53,
#    'image_id': 29,
#    'category_id': 1,
#    'segmentation': {'counts': [20606,
#      9,
#      212,
#      17,
#      206,
#      21,
#      202,
#      25,
#      199,
#      27,
#      196,
#      30,
#      194,
#      33,
#      191,
#      35,
#      190,
#      35,
#      189,
#      37,
#      187,
#      39,
#      186,
#      39,
#      185,
#      41,
#      184,
#      41,
#      183,
#      43,
#      182,
#      43,
#      182,
#      43,
#      181,
#      45,
#      180,
#      45,
#      180,
#      45,
#      180,
#      45,
#      180,
#      45,
#      180,
#      45,
#      180,
#      45,
#      180,
#      45,
#      180,
#      45,
#      181,
#      43,
#      182,
#      43,
#      182,
#      43,
#      183,
#      41,
#      184,
#      41,
#      185,
#      39,
#      186,
#      39,
#      187,
#      37,
#      189,
#      35,
#      191,
#      33,
#      192,
#      33,
#      193,
#      30,
#      197,
#      27,
#      199,
#      25,
#      202,
#      21,
#      206,
#      17,
#      212,
#      9,
#      20560],
#     'size': [225, 225]},
#    'area': 1519.0,
#    'bbox': [91.0, 113.0, 43.0, 45.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 54,
#    'image_id': 30,
#    'category_id': 1,
#    'segmentation': {'counts': [21268,
#      11,
#      168,
#      19,
#      162,
#      23,
#      158,
#      27,
#      155,
#      29,
#      152,
#      33,
#      149,
#      35,
#      147,
#      37,
#      144,
#      41,
#      141,
#      43,
#      140,
#      43,
#      139,
#      45,
#      137,
#      47,
#      135,
#      49,
#      134,
#      49,
#      134,
#      49,
#      133,
#      51,
#      132,
#      51,
#      131,
#      53,
#      130,
#      53,
#      129,
#      55,
#      128,
#      55,
#      128,
#      55,
#      128,
#      55,
#      127,
#      57,
#      126,
#      57,
#      126,
#      57,
#      126,
#      57,
#      126,
#      57,
#      126,
#      57,
#      126,
#      57,
#      126,
#      57,
#      126,
#      57,
#      126,
#      57,
#      126,
#      57,
#      127,
#      55,
#      128,
#      55,
#      128,
#      55,
#      128,
#      55,
#      129,
#      53,
#      130,
#      53,
#      130,
#      53,
#      131,
#      51,
#      133,
#      49,
#      134,
#      49,
#      134,
#      49,
#      135,
#      47,
#      137,
#      45,
#      139,
#      43,
#      140,
#      43,
#      141,
#      41,
#      144,
#      37,
#      147,
#      35,
#      149,
#      33,
#      152,
#      29,
#      155,
#      27,
#      158,
#      23,
#      162,
#      19,
#      168,
#      11,
#      18432],
#     'size': [183, 275]},
#    'area': 2645.0,
#    'bbox': [116.0, 17.0, 59.0, 57.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}},
#   {'id': 55,
#    'image_id': 30,
#    'category_id': 1,
#    'segmentation': {'counts': [4063,
#      11,
#      169,
#      18,
#      162,
#      23,
#      158,
#      28,
#      154,
#      30,
#      151,
#      33,
#      148,
#      36,
#      146,
#      39,
#      143,
#      41,
#      141,
#      43,
#      139,
#      45,
#      138,
#      45,
#      137,
#      47,
#      136,
#      47,
#      135,
#      49,
#      133,
#      51,
#      132,
#      51,
#      131,
#      53,
#      130,
#      53,
#      130,
#      53,
#      130,
#      53,
#      129,
#      55,
#      128,
#      55,
#      128,
#      55,
#      128,
#      55,
#      128,
#      55,
#      128,
#      55,
#      128,
#      55,
#      128,
#      55,
#      128,
#      55,
#      129,
#      53,
#      130,
#      53,
#      130,
#      53,
#      131,
#      51,
#      132,
#      51,
#      132,
#      51,
#      133,
#      49,
#      134,
#      49,
#      135,
#      47,
#      136,
#      47,
#      138,
#      43,
#      140,
#      43,
#      141,
#      41,
#      143,
#      39,
#      145,
#      36,
#      149,
#      33,
#      152,
#      30,
#      154,
#      28,
#      157,
#      23,
#      163,
#      18,
#      168,
#      11,
#      37101],
#     'size': [183, 275]},
#    'area': 2193.0,
#    'bbox': [22.0, 15.0, 51.0, 55.0],
#    'iscrowd': 1,
#    'attributes': {'occluded': False}}]}

# %%
def load_image(image_path):
    image = cv2.imread(image_path)
    if image is None:
        raise FileNotFoundError(f'이미지를 찾을 수 없음: {image_path}')
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
load_image(data_list[2])
# Out:
# array([[[100,  81,  64],
#         [ 97,  76,  57],
#         [103,  76,  55],
#         ...,
#         [177, 144, 135],
#         [177, 144, 135],
#         [177, 144, 135]],
#
#        [[ 99,  73,  58],
#         [ 92,  63,  49],
#         [ 97,  64,  49],
#         ...,
#         [182, 146, 130],
#         [182, 146, 130],
#         [182, 146, 130]],
#
#        [[130,  93,  75],
#         [117,  78,  61],
#         [122,  78,  65],
#         ...,
#         [189, 157, 136],
#         [189, 157, 136],
#         [189, 157, 136]],
#
#        ...,
#
#        [[160,  72,  32],
#         [134,  47,   4],
#         [143,  55,   7],
#         ...,
#         [ 66,  45,  42],
#         [ 66,  45,  42],
#         [ 66,  45,  42]],
#
#        [[211,  99,  17],
#         [211, 101,   4],
#         [211, 103,   0],
#         ...,
#         [ 59,  42,  50],
#         [ 59,  42,  50],
#         [ 59,  42,  50]],
#
#        [[222, 110,  24],
#         [222, 112,  14],
#         [222, 115,   1],
#         ...,
#         [ 59,  42,  50],
#         [ 59,  42,  50],
#         [ 59,  42,  50]]], dtype=uint8)

# %%
# 폴리곤 및 RLE 주석을 이미지 위에 그리기
# RLE(Run-Length Encoding): 이미지 압축 및 데이터 압축을 위한 기법 중 하나.
# 특히 COCO Datasets의 객체 분할시 정보를 저장할 때 많이 사용됨
def draw_annotations(image, annotations, image_id):
    for ann in annotations:
        if ann['image_id'] == image_id and 'segmentation' in ann:
            segmentation = ann['segmentation']

            # RLE 형식(딕셔너리 타입)
            if isinstance(segmentation, dict) and 'counts' in segmentation:
                try:
                    if isinstance(segmentation['counts'], list):
                        rle = maskUtils.frPyObjects(segmentation, segmentation['size'][0], segmentation['size'][1])
                        mask = maskUtils.decode(rle)
                    else:
                        mask = maskUtils.decode(rle)

                    contours, _ = cv2.findContours(mask.astype(np.uint8), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
                    cv2.drawContours(image, contours, -1, (255, 0, 0), 2)
                except Exception as e:
                    print(f'에러가 발생: {e}')

            # 폴리곤 형식(리스트 타입)
            elif isinstance(segmentation, list):
                for seg in segmentation:
                    if isinstance(seg, list) and len(seg) >= 6:
                        points = np.array(seg).reshape(-1, 2).astype(np.int32)
                        cv2.polylines(image, [points], isClosed=True, color=(0, 255, 0), thickness=2)

    return image

# %%
# 메인 실행 함수
def visualize_coco(json_path, image_folder, image_id):
    coco_data = load_coco_annotations(json_path)
    image_info = next((img for img in coco_data['images'] if img['id'] == image_id), None)
    if not image_info:
        raise ValueError(f'Image ID {image_id} not found in COCO JSON file')

    image_path = os.path.join(image_folder, image_info['file_name'])
    image = load_image(image_path)
    annotated_image = draw_annotations(image, coco_data['annotations'], image_id)

    plt.figure(figsize=(8, 6))
    plt.imshow(annotated_image)
    plt.axis('off')
    plt.title(f'Image ID: {image_id} with Annotations')
    plt.show()

# %%
visualize_coco(f'{data_root}/instances_default.json', f'{data_root}', 20)

# %%
visualize_coco(f'{data_root}/instances_default.json', f'{data_root}', 21)

# %%
# COCO JSON 파일 경로와 YOLO 저장할 폴더
coco_json_path = f'{data_root}/instances_default.json'
yolo_output_folder = f'{data_root}'
image_folder = f'{data_root}/'

# YOLO 라벨 폴더 생성(없으면 생성)
os.makedirs(yolo_output_folder, exist_ok=True)

# COCO JSON 로드
with open(coco_json_path, 'r') as f:
    coco_data = json.load(f)

# 이미지 정보 불러오기
image_dict = {img['id']: img for img in coco_data['images']}
image_dict
# Out:
# {1: {'id': 1,
#   'width': 236,
#   'height': 214,
#   'file_name': 'starbucks11.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  2: {'id': 2,
#   'width': 201,
#   'height': 251,
#   'file_name': 'starbucks12.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  3: {'id': 3,
#   'width': 395,
#   'height': 128,
#   'file_name': 'starbucks13.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  4: {'id': 4,
#   'width': 301,
#   'height': 167,
#   'file_name': 'starbucks14.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  5: {'id': 5,
#   'width': 275,
#   'height': 183,
#   'file_name': 'starbucks15.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  6: {'id': 6,
#   'width': 299,
#   'height': 168,
#   'file_name': 'starbucks16.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  7: {'id': 7,
#   'width': 275,
#   'height': 183,
#   'file_name': 'starbucks17.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  8: {'id': 8,
#   'width': 276,
#   'height': 183,
#   'file_name': 'starbucks18.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  9: {'id': 9,
#   'width': 275,
#   'height': 183,
#   'file_name': 'starbucks19.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  10: {'id': 10,
#   'width': 259,
#   'height': 194,
#   'file_name': 'starbucks20.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  11: {'id': 11,
#   'width': 259,
#   'height': 194,
#   'file_name': 'starbucks21.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  12: {'id': 12,
#   'width': 259,
#   'height': 194,
#   'file_name': 'starbucks22.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  13: {'id': 13,
#   'width': 225,
#   'height': 225,
#   'file_name': 'starbucks23.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  14: {'id': 14,
#   'width': 300,
#   'height': 168,
#   'file_name': 'starbucks24.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  15: {'id': 15,
#   'width': 280,
#   'height': 180,
#   'file_name': 'starbucks25.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  16: {'id': 16,
#   'width': 275,
#   'height': 183,
#   'file_name': 'starbucks26.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  17: {'id': 17,
#   'width': 275,
#   'height': 183,
#   'file_name': 'starbucks27.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  18: {'id': 18,
#   'width': 225,
#   'height': 225,
#   'file_name': 'starbucks28.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  19: {'id': 19,
#   'width': 225,
#   'height': 225,
#   'file_name': 'starbucks29.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  20: {'id': 20,
#   'width': 318,
#   'height': 159,
#   'file_name': 'starbucks30.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  21: {'id': 21,
#   'width': 264,
#   'height': 191,
#   'file_name': 'starbucks31.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  22: {'id': 22,
#   'width': 259,
#   'height': 194,
#   'file_name': 'starbucks32.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  23: {'id': 23,
#   'width': 225,
#   'height': 225,
#   'file_name': 'starbucks33.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  24: {'id': 24,
#   'width': 275,
#   'height': 183,
#   'file_name': 'starbucks34.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  25: {'id': 25,
#   'width': 259,
#   'height': 194,
#   'file_name': 'starbucks35.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  26: {'id': 26,
#   'width': 190,
#   'height': 265,
#   'file_name': 'starbucks36.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  27: {'id': 27,
#   'width': 275,
#   'height': 183,
#   'file_name': 'starbucks37.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  28: {'id': 28,
#   'width': 298,
#   'height': 169,
#   'file_name': 'starbucks38.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  29: {'id': 29,
#   'width': 225,
#   'height': 225,
#   'file_name': 'starbucks39.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0},
#  30: {'id': 30,
#   'width': 275,
#   'height': 183,
#   'file_name': 'starbucks40.jpg',
#   'license': 0,
#   'flickr_url': '',
#   'coco_url': '',
#   'date_captured': 0}}

# %%
# COCO -> YOLO 변환
for ann in coco_data['annotations']:
    image_id = ann['image_id']
    category_id = ann['category_id'] - 1 # YOLO는 class_id가 0부터 시작
    segmentation = ann['segmentation']

    image_info = image_dict.get(image_id)
    if not image_info:
        continue

    img_width, img_height = image_info['width'], image_info['height']
    # os.path.splitext: 파일 경로에서 확장자를 분리
    yolo_label_path = os.path.join(yolo_output_folder, f"{os.path.splitext(image_info['file_name'])[0]}.txt")

    yolo_lines = []

    for seg in segmentation:
        if isinstance(seg, list) and len(seg) >= 6:
            normalized_points = [
                (seg[i] / img_width, seg[i+1] / img_height) for i in range(0, len(seg), 2)
            ]
            yolo_line = f'{category_id} ' + ' '.join([f'{x:.6f} {y:6f}' for x, y in normalized_points])
            yolo_lines.append(yolo_line)

    if yolo_lines:
        with open(yolo_label_path, 'w') as f:
            f.write('\n'.join(yolo_lines))
print('coco -> yolo 변환 완료!')
# Out:
# coco -> yolo 변환 완료!

# %%
random.seed(2025)

data_list = glob.glob(f'{data_root}/*jpg') + glob.glob(f'{data_root}/*.jpeg')

random.shuffle(data_list)
test_ratio = 0.2
num_data = len(data_list)
num_data
# Out:
# 30

# %%
test_list = data_list[:int(num_data*test_ratio)]
valid_list = data_list[int(num_data*test_ratio):int(num_data*test_ratio)*2]
train_list = data_list[int(num_data*test_ratio)*2:]

len(test_list), len(valid_list), len(train_list)
# Out:
# (6, 6, 18)

# %%
file_root = f'{data_root}'
train_root = f'{data_root}/train'
valid_root = f'{data_root}/valid'
test_root = f'{data_root}/test'

for folder in [train_root, valid_root, test_root]:
    if not os.path.exists(folder):
        os.makedirs(folder)

# %%
# 파일 복사 함수(이미지 + 동일한 이름의 txt 파일)
def copy_files(file_list, dest_folder):
    for file_path in file_list:
        file_name = os.path.basename(file_path) # 파일 이름 추출 apple.jpg
        file_base, ext = os.path.splitext(file_name) # apple jpg

        # 원본(이미지) 파일 복사
        dest_path = os.path.join(dest_folder, file_name)
        shutil.copy(file_path, dest_path)

        # 텍스트 파일도 복사
        txt_file_path = os.path.join(os.path.dirname(file_path), f'{file_base}.txt')
        if os.path.exists(txt_file_path):
            dest_txt_path = os.path.join(dest_folder, f'{file_base}.txt')
            shutil.copy(txt_file_path, dest_txt_path)

# %%
copy_files(train_list, train_root)
copy_files(valid_list, valid_root)
copy_files(test_list, test_root)

# %%
train_root = f'/content/starbucks/starbucks/train'
valid_root = f'/content/starbucks/starbucks/valid'
test_root = f'/content/starbucks/starbucks/test'

# %%
import yaml

# %%
data = dict()
data['train'] = train_root
data['val'] = valid_root
data['test'] = test_root
data['nc'] = 2
data['names'] = ['logo', 'text']

with open(f'./starbucks/starbucks.yaml', 'w') as f:
    yaml.dump(data, f)

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8s-seg.pt')

# %%
results = model.train(
    data='./starbucks/starbucks.yaml',
    epochs = 10,
    batch=4,
    imgsz=224,
    device=0,
    workers=2,
    amp=False,
    name='starbucks_s'
)
# Out:
# Ultralytics 8.3.177 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=False, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=./starbucks/starbucks.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=starbucks_s2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/segment/starbucks_s2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2771318  ultralytics.nn.modules.head.Segment          [2, 32, 128, [128, 256, 512]]
# YOLOv8s-seg summary: 151 layers, 11,790,870 parameters, 11,790,854 gradients, 42.7 GFLOPs
#
# Transferred 411/417 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 463.0±177.4 MB/s, size: 12.2 KB)
# train: Scanning /content/starbucks/starbucks/train.cache... 0 images, 18 backgrounds, 0 corrupt: 100%|██████████| 18/18 [00:00<?, ?it/s]
# WARNING ⚠️ Labels are missing or empty in /content/starbucks/starbucks/train.cache, training may not work correctly. See https://docs.ultralytics.com/datasets for dataset formatting guidance.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 202.9±92.3 MB/s, size: 9.3 KB)
# val: Scanning /content/starbucks/starbucks/valid.cache... 0 images, 6 backgrounds, 0 corrupt: 100%|██████████| 6/6 [00:00<?, ?it/s]
# WARNING ⚠️ Labels are missing or empty in /content/starbucks/starbucks/valid.cache, training may not work correctly. See https://docs.ultralytics.com/datasets for dataset formatting guidance.
# Plotting labels to runs/segment/starbucks_s2/labels.jpg...
# WARNING ⚠️ zero-size array to reduction operation maximum which has no identity
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 66 weight(decay=0.0), 77 weight(decay=0.0005), 76 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to runs/segment/starbucks_s2
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      0.77G          0          0      10.47          0          0        224: 100%|██████████| 5/5 [00:00<00:00,  7.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 15.43it/s]
#                    all          6          0          0          0          0          0          0          0          0          0
# WARNING ⚠️ no labels found in segment set, can not compute metrics without labels
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:850: RuntimeWarning: Mean of empty slice.
#   i = smooth(f1_curve.mean(0), 0.1).argmax()  # max F1 index
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/10     0.824G          0          0      5.732          0          0        224: 100%|██████████| 5/5 [00:00<00:00, 11.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 28.70it/s]
#                    all          6          0          0          0          0          0          0          0          0          0
# WARNING ⚠️ no labels found in segment set, can not compute metrics without labels
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:850: RuntimeWarning: Mean of empty slice.
#   i = smooth(f1_curve.mean(0), 0.1).argmax()  # max F1 index
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/10     0.939G          0          0      4.618          0          0        224: 100%|██████████| 5/5 [00:00<00:00, 15.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.90it/s]
#                    all          6          0          0          0          0          0          0          0          0          0
# WARNING ⚠️ no labels found in segment set, can not compute metrics without labels
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:850: RuntimeWarning: Mean of empty slice.
#   i = smooth(f1_curve.mean(0), 0.1).argmax()  # max F1 index
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/10     0.939G          0          0      4.026          0          0        224: 100%|██████████| 5/5 [00:00<00:00, 14.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 13.11it/s]
#                    all          6          0          0          0          0          0          0          0          0          0
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:850: RuntimeWarning: Mean of empty slice.
#   i = smooth(f1_curve.mean(0), 0.1).argmax()  # max F1 index
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# WARNING ⚠️ no labels found in segment set, can not compute metrics without labels
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      0.98G          0          0      3.498          0          0        224: 100%|██████████| 5/5 [00:00<00:00, 16.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 28.78it/s]
#                    all          6          0          0          0          0          0          0          0          0          0
# WARNING ⚠️ no labels found in segment set, can not compute metrics without labels
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:850: RuntimeWarning: Mean of empty slice.
#   i = smooth(f1_curve.mean(0), 0.1).argmax()  # max F1 index
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      0.98G          0          0      3.115          0          0        224: 100%|██████████| 5/5 [00:00<00:00, 13.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 28.26it/s]
#                    all          6          0          0          0          0          0          0          0          0          0
# WARNING ⚠️ no labels found in segment set, can not compute metrics without labels
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:850: RuntimeWarning: Mean of empty slice.
#   i = smooth(f1_curve.mean(0), 0.1).argmax()  # max F1 index
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      1.02G          0          0      2.775          0          0        224: 100%|██████████| 5/5 [00:00<00:00, 14.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 28.79it/s]
#                    all          6          0          0          0          0          0          0          0          0          0
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:850: RuntimeWarning: Mean of empty slice.
#   i = smooth(f1_curve.mean(0), 0.1).argmax()  # max F1 index
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# WARNING ⚠️ no labels found in segment set, can not compute metrics without labels
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        8/10       1.1G          0          0      2.402          0          0        224: 100%|██████████| 5/5 [00:00<00:00, 12.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 17.53it/s]
#                    all          6          0          0          0          0          0          0          0          0          0
# WARNING ⚠️ no labels found in segment set, can not compute metrics without labels
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:850: RuntimeWarning: Mean of empty slice.
#   i = smooth(f1_curve.mean(0), 0.1).argmax()  # max F1 index
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        9/10       1.1G          0          0      2.304          0          0        224: 100%|██████████| 5/5 [00:00<00:00,  9.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 16.06it/s]
#                    all          6          0          0          0          0          0          0          0          0          0
# WARNING ⚠️ no labels found in segment set, can not compute metrics without labels
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:850: RuntimeWarning: Mean of empty slice.
#   i = smooth(f1_curve.mean(0), 0.1).argmax()  # max F1 index
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       10/10       1.1G          0          0      2.238          0          0        224: 100%|██████████| 5/5 [00:00<00:00, 11.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 28.84it/s]
#                    all          6          0          0          0          0          0          0          0          0          0
# WARNING ⚠️ no labels found in segment set, can not compute metrics without labels
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:850: RuntimeWarning: Mean of empty slice.
#   i = smooth(f1_curve.mean(0), 0.1).argmax()  # max F1 index
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# 10 epochs completed in 0.004 hours.
# Optimizer stripped from runs/segment/starbucks_s2/weights/last.pt, 23.8MB
# Optimizer stripped from runs/segment/starbucks_s2/weights/best.pt, 23.8MB
#
# Validating runs/segment/starbucks_s2/weights/best.pt...
# Ultralytics 8.3.177 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8s-seg summary (fused): 85 layers, 11,780,374 parameters, 0 gradients, 42.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 20.40it/s]
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:668: RuntimeWarning: Mean of empty slice.
#   ax.plot(px, py.mean(1), linewidth=3, color="blue", label=f"all classes {ap[:, 0].mean():.3f} mAP@0.5")
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:713: RuntimeWarning: Mean of empty slice.
#   y = smooth(py.mean(0), 0.1)
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:713: RuntimeWarning: Mean of empty slice.
#   y = smooth(py.mean(0), 0.1)
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:713: RuntimeWarning: Mean of empty slice.
#   y = smooth(py.mean(0), 0.1)
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:850: RuntimeWarning: Mean of empty slice.
#   i = smooth(f1_curve.mean(0), 0.1).argmax()  # max F1 index
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:668: RuntimeWarning: Mean of empty slice.
#   ax.plot(px, py.mean(1), linewidth=3, color="blue", label=f"all classes {ap[:, 0].mean():.3f} mAP@0.5")
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:713: RuntimeWarning: Mean of empty slice.
#   y = smooth(py.mean(0), 0.1)
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:713: RuntimeWarning: Mean of empty slice.
#   y = smooth(py.mean(0), 0.1)
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:713: RuntimeWarning: Mean of empty slice.
#   y = smooth(py.mean(0), 0.1)
# /usr/local/lib/python3.11/dist-packages/numpy/_core/_methods.py:130: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py:850: RuntimeWarning: Mean of empty slice.
#   i = smooth(f1_curve.mean(0), 0.1).argmax()  # max F1 index
#                    all          6          0          0          0          0          0          0          0          0          0
# WARNING ⚠️ no labels found in segment set, can not compute metrics without labels
# Speed: 0.1ms preprocess, 2.7ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to runs/segment/starbucks_s2

# %%
model = YOLO('runs/segment/starbucks_s2/weights/best.pt')

# %%
results = model.predict(
    source=test_root,
    imgsz=224,
    conf=0.25,
    device=0,
    save=True,
    save_conf=True
)
# Out:
# image 1/6 /content/starbucks/starbucks/test/starbucks12.jpg: 224x192 (no detections), 13.6ms
# image 2/6 /content/starbucks/starbucks/test/starbucks17.jpg: 160x224 (no detections), 10.6ms
# image 3/6 /content/starbucks/starbucks/test/starbucks18.jpg: 160x224 (no detections), 9.2ms
# image 4/6 /content/starbucks/starbucks/test/starbucks20.jpg: 192x224 (no detections), 10.3ms
# image 5/6 /content/starbucks/starbucks/test/starbucks30.jpg: 128x224 (no detections), 10.3ms
# image 6/6 /content/starbucks/starbucks/test/starbucks34.jpg: 160x224 (no detections), 10.2ms
# Speed: 0.7ms preprocess, 10.7ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 224)
# Results saved to runs/segment/predict2
